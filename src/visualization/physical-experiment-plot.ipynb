# %%
# physical experiments result
import matplotlib.pyplot as plt
import matplotlib.patches as patches
import tikzplotlib

# %%
# obj mean
escape_depth = [0.1697260452, 0.3342074684, 0.4599809861, 0.09200999502, 0.1500594512, 0.2524673438, 0.2809728784, 0.3879901447, 0.5039077638, 0.2578059871, 0.3836056399, 0.5369652167]
escape_energy = [9.657072522, 19.01573653, 26.17199815, 1.805236102, 2.944166432, 4.953409285, 8.8203006, 12.17978662, 15.81867252, 8.093045547, 12.04214825, 16.85641208]
perturbation_level = [0.41375, 0.63125, 0.7925, 0.35375, 0.46625, 0.6425, 0.43625, 0.48125, 0.68, 0.51875, 0.62375, 0.8075]

# obj std
perturbation_level_std = [0.05423164601, 0.08322731351, 0.05946187254, 0.04068608046, 0.08991066995, 0.06755949759, 0.06696214282, 0.0716015762, 0.09071147352, 0.08166788143, 0.07595816518, 0.09721111048]
escape_energy_std = [0.08417054148, 0.07383068223, 0.07079242009, 0.5103922977, 0.08411557192, 0.05418117366, 0.4397743295, 0.3370757156, 0.3545360554, 0.2439386013, 0.3589082017, 0.2718447905]
escape_depth_std = [0.001479323377, 0.001297597143, 0.001244198743, 0.02601387858, 0.004287236082, 0.00276152771, 0.0140091211, 0.0107376311, 0.01129383459, 0.007770725066, 0.0114331104, 0.008659683695]


# donuts data
perturbation_level1 = [0.53375, 0.5825, 0.63125, 0.6875]
escape_energy1 = [8.056240975, 9.964778245, 10.71525944, 12.31735902]
escape_depth1 = [0.2831818684, 0.3078113936, 0.322336502633477, 0.3304189876]

# donuts perturbation
perturbation_level1_std = [0.07069805008, 0.1060660172, 0.09203066259, 0.1432031524]
escape_energy1_std = [0.4740181219, 0.7654654989, 0.6088174606, 1.120198854]
escape_depth1_std = [0.01666203107, 0.02364518268, 0.01723913978, 0.03004986464]

cls = ['#31a354', '#756bb1', '#2b8cbe', '#f4a63e', '#FF69B4', '#f03b20', ]

# %%
# Create scatter plot
colors = [cls[0]]*3 + [cls[1]]*3 + [cls[2]]*3 + [cls[3]]*3
shapes = ['s', '^', 'D']*4
labels = ['ball', 'glue', 'banana', 'tape']

fig, ax = plt.subplots()

# Add mean dots and std ellipses
i = 0
for x, y, std_x, std_y in zip(escape_depth, perturbation_level, escape_depth_std, perturbation_level_std):
    ax.scatter(x, y, marker=shapes[i], color=colors[i])
    # ellipse = patches.Ellipse((x, y), std_x*2, std_y*2, alpha=0.3, color=colors[i])
    # ax.add_patch(ellipse)
    i += 1

# Create custom handles and labels for the legend
custom_handles = [plt.Line2D([], [], marker='^', color='black', label='bowl S', linestyle='None'),
                  plt.Line2D([], [], marker='s', color='black', label='bowl M', linestyle='None'),
                  plt.Line2D([], [], marker='o', color='black', label='bowl L', linestyle='None'),
                  patches.Ellipse((100,100), 1, 1, alpha=1, color=cls[0], label=labels[0]),
                  patches.Ellipse((100,100), 1, 1, alpha=1, color=cls[1], label=labels[1]),
                  patches.Ellipse((100,100), 1, 1, alpha=1, color=cls[2], label=labels[2]),
                  patches.Ellipse((100,100), 1, 1, alpha=1, color=cls[3], label=labels[3]),
                  ]

# Set labels and title
ax.set_xlabel('Escape Depth (dm)')
ax.set_ylabel('Perturbation Level')
# ax.legend(handles=custom_handles)
# ax.legend()
ax.set_xlim(0.03,0.58)
ax.set_ylim(0.3,0.92)

# ax.set_title('Escape Depth vs. Perturbation Level')

# Display the plot
# plt.show()
# tikzplotlib.save('phys-experi.tex')

# %%
# Create scatter plot
labels = ['120\u00B0', '90\u00B0', '60\u00B0', '45\u00B0']

fig, ax = plt.subplots()

# Add mean dots and std ellipses
i = 0
for x, y, std_x, std_y in zip(escape_depth1, perturbation_level1, escape_depth1_std, perturbation_level1_std):
    ax.scatter(x, y, color=cls[i])
    ellipse = patches.Ellipse((x, y), std_x*2, std_y*2, alpha=0.3, color=cls[i])
    ax.add_patch(ellipse)
    i += 1

# Create custom handles and labels for the legend
custom_handles = [patches.Ellipse((100,100), 1, 1, alpha=1, color=cls[0], label=labels[0]),
                  patches.Ellipse((100,100), 1, 1, alpha=1, color=cls[1], label=labels[1]),
                  patches.Ellipse((100,100), 1, 1, alpha=1, color=cls[2], label=labels[2]),
                  patches.Ellipse((100,100), 1, 1, alpha=1, color=cls[3], label=labels[3]),
                  ]

# Set labels and title
ax.set_xlabel('Escape Depth (dm)')
ax.set_ylabel('Perturbation Level')
ax.legend(handles=custom_handles)
# ax.legend()
ax.set_xlim(0.25,0.36)
ax.set_ylim(0.4,0.86)

# ax.set_title('Escape Depth vs. Perturbation Level')

# Display the plot
plt.show()

# %%
# Create a figure with two subplots
fig, axs = plt.subplots(1, 2, figsize=(8, 4), gridspec_kw={'width_ratios': [7, 3]})

# Left plot (70%)
# Add mean dots and std ellipses
i = 0
for x, y, std_x, std_y in zip(escape_depth, perturbation_level, escape_depth_std, perturbation_level_std):
    if i == 9:
        axs[0].scatter(x, y, marker=shapes[i], color='black')
    else:
        axs[0].scatter(x, y, marker=shapes[i], facecolors='none', color='black')
    ellipse = patches.Ellipse((x, y), std_x*2, std_y*2, alpha=0.3, color=colors[i])
    axs[0].add_patch(ellipse)
    i += 1

# Create custom handles and labels for the legend
labels = ['ball', 'glue', 'banana', 'tape']
custom_handles = [plt.Line2D([], [], marker=shapes[0], fillstyle='none', color='black', label='bowl S', linestyle='None'),
                  plt.Line2D([], [], marker=shapes[1], fillstyle='none', color='black', label='bowl M', linestyle='None'),
                  plt.Line2D([], [], marker=shapes[2], fillstyle='none', color='black', label='bowl L', linestyle='None'),
                  patches.Ellipse((100,100), 1, 1, alpha=1, color=cls[0], label=labels[0]),
                  patches.Ellipse((100,100), 1, 1, alpha=1, color=cls[1], label=labels[1]),
                  patches.Ellipse((100,100), 1, 1, alpha=1, color=cls[2], label=labels[2]),
                  patches.Ellipse((100,100), 1, 1, alpha=1, color=cls[3], label=labels[3]),
                  ]

# Set labels and title
axs[0].set_xlabel('escape depth / dm')
axs[0].set_ylabel('perturbation level')
axs[0].legend(handles=custom_handles)
axs[0].set_xlim(0.03,0.58)
axs[0].set_ylim(0.3,0.92)

# Right plot (30%)
# Add mean dots
i = 0
for x, y, std_x, std_y in zip(escape_depth1, perturbation_level1, escape_depth1_std, perturbation_level1_std):
    ellipse = patches.Ellipse((x, y), std_x*2, std_y*2, alpha=0.3, color=cls[i])
    axs[1].add_patch(ellipse)
    i += 1

# Add std ellipses
i = 0
for x, y, std_x, std_y in zip(escape_depth1, perturbation_level1, escape_depth1_std, perturbation_level1_std):
    if i == 3:
        axs[1].scatter(x, y, marker='s', color='black')
    else:
        axs[1].scatter(x, y, marker='s', facecolors='none', color='black')
    i += 1

# Create custom handles and labels for the legend
labels = ['120\u00B0', '90\u00B0', '60\u00B0', '45\u00B0']
custom_handles = [patches.Ellipse((100,100), 1, 1, alpha=1, color=cls[0], label=labels[0]),
                  patches.Ellipse((100,100), 1, 1, alpha=1, color=cls[1], label=labels[1]),
                  patches.Ellipse((100,100), 1, 1, alpha=1, color=cls[2], label=labels[2]),
                  patches.Ellipse((100,100), 1, 1, alpha=1, color=cls[3], label=labels[3]),
                  ]

# Set labels and title
axs[1].set_xlabel('escape depth / dm')
axs[1].set_ylabel('perturbation level')
axs[1].legend(handles=custom_handles)
# ax.legend()
axs[1].set_xlim(0.25,0.36)
axs[1].set_ylim(0.4,0.86)

# Adjust spacing between plots
plt.subplots_adjust(wspace=0.3)

# Display the figure
# plt.show()
# tikzplotlib.save('phys-experi.tex')
plt.savefig("donut1.png", dpi=300)

# %%
# Create scatter plot
plt.scatter(escape_energy[:3], perturbation_level[:3])
plt.scatter(escape_energy[3:6], perturbation_level[3:6])
plt.scatter(escape_energy[6:9], perturbation_level[6:9])
plt.scatter(escape_energy[9:], perturbation_level[9:])
plt.scatter(escape_energy1, perturbation_level1)
plt.xlabel('Escape Energy (mJ)')
plt.ylabel('Perturbation Level')
plt.title('Scatter Plot of Escape Energy vs. Perturbation Level')

# Display the plot
plt.show()
